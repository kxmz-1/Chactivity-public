# %%
log_path: str = r"C:\Users\neko\Downloads\spotify_activity.log"
# base_activity_prefix = ""

with open(log_path, "r", encoding="utf-8") as f:
    explored: list[str] = list(set([i.split("\t")[0] for i in f.read().strip().split("\n")]))

# %%
sheet_lines = r"""com.spotify.music	com.spotify.adsdisplay.browser.inapp.InAppBrowserActivity
com.spotify.music	com.spotify.adsdisplay.display.DisplayAdActivity
com.spotify.music	com.spotify.adsdisplay.products.cmp.CMPActivity
com.spotify.music	com.spotify.adsinternal.adscommon.inappbrowser.InAppBrowserLauncherActivity
com.spotify.music	com.spotify.ageverification.dialog.view.AgeVerificationDialogActivity
com.spotify.music	com.spotify.allboarding.allboardingimpl.AllboardingActivity
com.spotify.music	com.spotify.android.permissionsimpl.PermissionsRequestActivity
com.spotify.music	com.spotify.appauthorization.externallogin.LoginRedirectActivity
com.spotify.music	com.spotify.appauthorization.sso.AuthorizationActivity
com.spotify.music	com.spotify.appauthorization.sso.internalauth.AuthorizationActivityInternalProxy
com.spotify.music	com.spotify.appauthorization.sso.util.AfterLoginDummyActivity
com.spotify.music	com.spotify.appendix.slateimpl.SlateModalActivity
com.spotify.music	com.spotify.apprater.appraterdialog.AppRaterActivity
com.spotify.music	com.spotify.assistedcuration.page.search.AssistedCurationSearchActivity
com.spotify.music	com.spotify.blend.tastematch.BlendStoryContainerActivity
com.spotify.music	com.spotify.blend.tastematch.BlendTasteMatchActivity
com.spotify.music	com.spotify.campaigns.wrapped2023.stories.container.Wrapped2023StoriesActivity
com.spotify.music	com.spotify.carmobile.waze.WazeReturnActivity
com.spotify.music	com.spotify.checkout.checkoutnative.web.PremiumSignupActivity
com.spotify.music	com.spotify.connect.devicepickerimpl.DevicePickerActivity
com.spotify.music	com.spotify.connect.mediarouteprovider.OutputSwitcherActivity
com.spotify.music	com.spotify.connect.volumeimpl.widget.RemoteVolumeWidgetActivity
com.spotify.music	com.spotify.contentpromotion.promos.hubs.CoverImageActivity
com.spotify.music	com.spotify.effortlesslogin.effortlesslogin.EffortlessLoginActivity
com.spotify.music	com.spotify.email.editemail.sso.SsoUpdateEmailActivity
com.spotify.music	com.spotify.endless.sessionstarter.EndlessActivity
com.spotify.music	com.spotify.facebookconnect.facebookconnectimpl.FacebookConnectActivity
com.spotify.music	com.spotify.freetierallsongsdialog.freetierallsongsdialog.FreeTierAllSongsDialogActivity
com.spotify.music	com.spotify.fullscreenstory.fullscreenstoryimpl.FullscreenStoryActivity
com.spotify.music	com.spotify.genalpha.accountselectionimpl.AccountSelectionActivity
com.spotify.music	com.spotify.gpb.choicescreenpage.ChoiceScreenActivity
com.spotify.music	com.spotify.gpb.countrypicker.CountryPickerActivity
com.spotify.music	com.spotify.gpb.googlecheckout.GoogleCheckoutActivity
com.spotify.music	com.spotify.gpb.unifiedcheckout.CheckoutSessionActivity
com.spotify.music	com.spotify.hype.promodisclosureimpl.PromoDisclosureActivity
com.spotify.music	com.spotify.liveevents.concertsentity.webview.TicketingFlowActivity
com.spotify.music	com.spotify.liveevents.ontourdisclosure.OnTourDisclosureActivity
com.spotify.music	com.spotify.login.loginflowimpl.LoginActivity
com.spotify.music	com.spotify.login.loginflowimpl.QuickLoginActivity
com.spotify.music	com.spotify.login.magiclinkapi.setpassword.MagicLinkSetPasswordActivity
com.spotify.music	com.spotify.login.phonenumbersignup.callingcode.CallingCodePickerActivity
com.spotify.music	com.spotify.lyrics.fullscreenview.page.LyricsFullscreenPageActivity
com.spotify.music	com.spotify.marquee.marquee.learnmore.LearnMoreWebActivity
com.spotify.music	com.spotify.marquee.marquee.MarqueeActivity
com.spotify.music	com.spotify.mediasession.mediasession.login.AfterLoginDummyActivity
com.spotify.music	com.spotify.messaging.churnlockedstate.ChurnLockedStateActivity
com.spotify.music	com.spotify.messaging.criticalmessaging.criticalmessagingview.internal.encorecomponents.webview.CriticalMessageWebViewActivity
com.spotify.music	com.spotify.messaging.messagingplatformimpl.slate.SlateMessageHostActivity
com.spotify.music	com.spotify.messaging.messagingutils.MessagingUtilsInternalWebviewActivity
com.spotify.music	com.spotify.messaging.premiummessaging.view.PremiumMessagingActivity
com.spotify.music	com.spotify.messaging.quicksilvermusicintegration.v2.inappinternalwebview.InAppInternalWebviewActivity
com.spotify.music	com.spotify.music.SpotifyMainActivity
com.spotify.music	com.spotify.musicappplatform.notificationwebview.NotificationWebViewActivity
com.spotify.music	com.spotify.musicappplatform.offlineerrors.OfflineDeviceLimitReachedActivity
com.spotify.music	com.spotify.nativeadshomeformats.nativeadshomeformats.impl.help.HelpWebViewActivity
com.spotify.music	com.spotify.nowplaying.musicinstallation.NowPlayingActivity
com.spotify.music	com.spotify.nowplayingqueue.queue.NowPlayingQueueActivity
com.spotify.music	com.spotify.partneraccountlinking.partneraccountlinking.PartnerAccountLinkingActivity
com.spotify.music	com.spotify.playlistcollaboration.invite.storyimpl.presentation.InviteStoryContainerActivity
com.spotify.music	com.spotify.playlistcuration.playlistallsongspage.PlaylistAllSongsActivity
com.spotify.music	com.spotify.premiumaccountmanagement.management.page.PremiumAccountManagementWebviewActivity
com.spotify.music	com.spotify.proactiveplatforms.recommendationswidget.RecommendationsWidgetProxyActivity
com.spotify.music	com.spotify.proactiveplatforms.widgetcommonlogic.WidgetsProxyActivity
com.spotify.music	com.spotify.profile.editprofile.editprofile.ChangeImageActivity
com.spotify.music	com.spotify.profile.editprofile.editprofile.ChangePronounsActivity
com.spotify.music	com.spotify.profile.editprofile.editprofile.ColorPickerActivity
com.spotify.music	com.spotify.profile.editprofile.editprofile.EditProfileActivity
com.spotify.music	com.spotify.ratings.ratingsandreviewspage.ui.RatingsActivity
com.spotify.music	com.spotify.remoteconfig.debugfeature.RemoteConfigurationDebugActivity
com.spotify.music	com.spotify.reporting.reportaction.ReportWebViewActivity
com.spotify.music	com.spotify.scannables.scannables.ScannablesActivity
com.spotify.music	com.spotify.scannables.scannables.view.ScannablesOnboardingActivity
com.spotify.music	com.spotify.settings.settings.deletecache.StorageDeleteCacheActivity
com.spotify.music	com.spotify.settings.settings.disableofflinelistening.StorageDisableOfflineListeningActivity
com.spotify.music	com.spotify.settings.settings.removedownloads.StorageRemoveDownloadsActivity
com.spotify.music	com.spotify.settings.settings.soundeffects.SoundEffectsWarningActivity
com.spotify.music	com.spotify.sociallistening.dialogsimpl.SocialListeningEducationActivity
com.spotify.music	com.spotify.sociallistening.dialogsimpl.SocialListeningInfoDialogActivity
com.spotify.music	com.spotify.sociallistening.dialogsimpl.SocialListeningIPLOnboardingActivity
com.spotify.music	com.spotify.sociallistening.dialogsimpl.SocialListeningIPLV2OnboardingActivity
com.spotify.music	com.spotify.sociallistening.notificationcenterimpl.dialogs.IPLDialogsHostActivity
com.spotify.music	com.spotify.sociallistening.participantlistimpl.SocialListeningActivity
com.spotify.music	com.spotify.sociallistening.sharecontainerimpl.SocialListeningShareContainerActivity
com.spotify.music	com.spotify.storage.localstorage.DiskAlmostFullActivity
com.spotify.music	com.spotify.storage.localstorage.MoveCacheConfirmationActivity
com.spotify.music	com.spotify.superbird.setup.SuperbirdSetupActivity
com.spotify.music	com.spotify.tome.pageactivity.PageActivity
com.spotify.music	com.spotify.trackcredits.trackcredits.TrackCreditsActivity
com.spotify.music	com.spotify.wear.pinpairing.PinPairingActivity
com.spotify.music	com.spotify.yourspotify.profile.page.YourSpotifyWebviewActivity""".strip()
slots = [i.split("\t") for i in sheet_lines.strip().split("\n")]

# %%
slots_new = slots[:]
for slot in slots:
    for exp in explored:
        if slot[1].endswith(exp):
            slots_new.remove(slot)
            break
print(f"{len(slots)=}, {len(explored)=}, {len(slots_new)=}")

from pyperclip import copy, paste

copy("\n".join(["\t".join(slot) for slot in slots_new]))
# Out:
# len(slots)=90, len(explored)=7, len(slots_new)=90
